# %%
# Import Dependencies
import json
import requests
import pprint
import pandas as pd
import matplotlib.pyplot as plt
# Import the EIA API key
from project_config import EIA_api_key

# %% [markdown]
# ### Generator Report API Pull - January 2020 to January 2023

# %%
# Define the API key
api_key = EIA_api_key
count = 0
json_array = []

# Loop to pull API results given 5000 results limit
for i in range(0,12):
    offset = 5000 * count
    url = f"https://api.eia.gov/v2/electricity/operating-generator-capacity/data/?api_key={api_key}&frequency=monthly&data[0]=latitude&data[1]=longitude&facets[stateid][]=TX&start=2020-01&end=2023-01&sort[0][column]=period&sort[0][direction]=desc&sort[1][column]=entityid&sort[1][direction]=asc&sort[2][column]=plantid&sort[2][direction]=asc&sort[3][column]=generatorid&sort[3][direction]=asc&offset={offset}&length=5000"

    # Send the API request
    response = requests.get(url)
    response.raise_for_status()

    # Retrieve the data
    data = response.json()
    data_clean = data["response"]["data"]
    for item in data_clean:
        json_array.append(item)
    count = count + 1

# %%
# Create Dataframe of Generator data
generator_full_df = pd.json_normalize(json_array)
print("Rows in Dataframe: ", len(generator_full_df))
generator_full_df.head()
# Out:
# Rows in Dataframe:  56365
#     period stateid stateName          sector      sectorName  entityid  \
# 0  2023-01      TX     Texas     ipp-non-chp     IPP Non-CHP       313
# 1  2023-01      TX     Texas     ipp-non-chp     IPP Non-CHP       313
# 2  2023-01      TX     Texas     ipp-non-chp     IPP Non-CHP       313
# 3  2023-01      TX     Texas  industrial-chp  Industrial CHP       327
# 4  2023-01      TX     Texas  industrial-chp  Industrial CHP       327
#
#                             entityName  plantid          plantName  \
# 0             Wolf Hollow I Power, LLC    55139   Wolf Hollow I LP
# 1             Wolf Hollow I Power, LLC    55139   Wolf Hollow I LP
# 2             Wolf Hollow I Power, LLC    55139   Wolf Hollow I LP
# 3  Air Liquide Large Industries U S LP    10298  Bayou Cogen Plant
# 4  Air Liquide Large Industries U S LP    10298  Bayou Cogen Plant
#
#   generatorid  ... energy_source_code energy-source-desc prime_mover_code  \
# 0        CTG1  ...                 NG        Natural Gas               CT
# 1        CTG2  ...                 NG        Natural Gas               CT
# 2          ST  ...                 NG        Natural Gas               CA
# 3         GT1  ...                 NG        Natural Gas               GT
# 4         GT2  ...                 NG        Natural Gas               GT
#
#   balancing_authority_code balancing-authority-name status statusDescription  \
# 0                     None                     None     OP         Operating
# 1                     None                     None     OP         Operating
# 2                     None                     None     OP         Operating
# 3                     None                     None     OP         Operating
# 4                     None                     None     OP         Operating
#
#    latitude  longitude  unit
# 0  32.33422 -97.731686  BLK1
# 1  32.33422 -97.731686  BLK1
# 2  32.33422 -97.731686  BLK1
# 3  29.62250 -95.045800  None
# 4  29.62250 -95.045800  None
#
# [5 rows x 21 columns]

# %%
# Confirm there are no duplicates in dataset as a result of for loop
generator_updated_df = generator_full_df.drop_duplicates()
print("Rows in Dataframe: ", len(generator_updated_df))
generator_updated_df.head()
# Out:
# Rows in Dataframe:  56365
#     period stateid stateName          sector      sectorName  entityid  \
# 0  2023-01      TX     Texas     ipp-non-chp     IPP Non-CHP       313
# 1  2023-01      TX     Texas     ipp-non-chp     IPP Non-CHP       313
# 2  2023-01      TX     Texas     ipp-non-chp     IPP Non-CHP       313
# 3  2023-01      TX     Texas  industrial-chp  Industrial CHP       327
# 4  2023-01      TX     Texas  industrial-chp  Industrial CHP       327
#
#                             entityName  plantid          plantName  \
# 0             Wolf Hollow I Power, LLC    55139   Wolf Hollow I LP
# 1             Wolf Hollow I Power, LLC    55139   Wolf Hollow I LP
# 2             Wolf Hollow I Power, LLC    55139   Wolf Hollow I LP
# 3  Air Liquide Large Industries U S LP    10298  Bayou Cogen Plant
# 4  Air Liquide Large Industries U S LP    10298  Bayou Cogen Plant
#
#   generatorid  ... energy_source_code energy-source-desc prime_mover_code  \
# 0        CTG1  ...                 NG        Natural Gas               CT
# 1        CTG2  ...                 NG        Natural Gas               CT
# 2          ST  ...                 NG        Natural Gas               CA
# 3         GT1  ...                 NG        Natural Gas               GT
# 4         GT2  ...                 NG        Natural Gas               GT
#
#   balancing_authority_code balancing-authority-name status statusDescription  \
# 0                     None                     None     OP         Operating
# 1                     None                     None     OP         Operating
# 2                     None                     None     OP         Operating
# 3                     None                     None     OP         Operating
# 4                     None                     None     OP         Operating
#
#    latitude  longitude  unit
# 0  32.33422 -97.731686  BLK1
# 1  32.33422 -97.731686  BLK1
# 2  32.33422 -97.731686  BLK1
# 3  29.62250 -95.045800  None
# 4  29.62250 -95.045800  None
#
# [5 rows x 21 columns]

# %%
# Create Sector Dataframe to store sectorID and name
sector_df = generator_full_df[["sector", "sectorName"]].drop_duplicates(ignore_index=True)
sector_df = sector_df.set_index("sector")
sector_df
# Out:
#                             sectorName
# sector
# ipp-non-chp                IPP Non-CHP
# industrial-chp          Industrial CHP
# electric-utility      Electric Utility
# ipp-chp                        IPP CHP
# industrial-non-chp  Industrial Non-CHP
# commercial-chp          Commercial CHP
# commercial-non-chp  Commercial Non-CHP

# %%
# Create Entity Dataframe to store entityID and name
entity_df = generator_full_df[["entityid", "entityName"]].drop_duplicates(ignore_index=True)
entity_df
# Out:
#      entityid                           entityName
# 0         313             Wolf Hollow I Power, LLC
# 1         327  Air Liquide Large Industries U S LP
# 2         429               Occidental Permian Ltd
# 3         914         Total Petrochemicals USA Inc
# 4        1015                        Austin Energy
# ..        ...                                  ...
# 395     62811         Sherbino Mesa I Windfarm LLC
# 396     63713                           CatanSolar
# 397     63884              Oklaunion Power Station
# 398     16668                      Sabine Cogen LP
# 399     56046           High Plains Wind Power LLC
#
# [400 rows x 2 columns]

# %%
# Remove duplicate entityIDs due to spelling or capitalization differences
entity_df_clean = entity_df.drop_duplicates(subset="entityid")
entity_df_clean = entity_df_clean.set_index("entityid")
entity_df_clean
# Out:
#                                    entityName
# entityid
# 313                  Wolf Hollow I Power, LLC
# 327       Air Liquide Large Industries U S LP
# 429                    Occidental Permian Ltd
# 914              Total Petrochemicals USA Inc
# 1015                            Austin Energy
# ...                                       ...
# 62811            Sherbino Mesa I Windfarm LLC
# 63713                              CatanSolar
# 63884                 Oklaunion Power Station
# 16668                         Sabine Cogen LP
# 56046              High Plains Wind Power LLC
#
# [393 rows x 1 columns]

# %%
# Create Plant Dataframe to store plantID and name
plant_df = generator_full_df[["plantid", "plantName"]].drop_duplicates(ignore_index=True)
plant_df
# Out:
#      plantid                   plantName
# 0      55139            Wolf Hollow I LP
# 1      10298           Bayou Cogen Plant
# 2      54748           Port Neches Plant
# 3      52122    Wasson CO2 Removal Plant
# 4      10568  Port Arthur Texas Refinery
# ..       ...                         ...
# 755    56779        Sherbino I Wind Farm
# 756      127                   Oklaunion
# 757     3477                   Lone Star
# 758    55104                Sabine Cogen
# 759    56834                 High Plains
#
# [760 rows x 2 columns]

# %%
# Remove duplicate plantIDs due to spelling or capitalization differences
plant_df_clean = plant_df.drop_duplicates(subset="plantid")
plant_df_clean = plant_df_clean.set_index("plantid")
plant_df_clean
# Out:
#                           plantName
# plantid
# 55139              Wolf Hollow I LP
# 10298             Bayou Cogen Plant
# 54748             Port Neches Plant
# 52122      Wasson CO2 Removal Plant
# 10568    Port Arthur Texas Refinery
# ...                             ...
# 56779          Sherbino I Wind Farm
# 127                       Oklaunion
# 3477                      Lone Star
# 55104                  Sabine Cogen
# 56834                   High Plains
#
# [754 rows x 1 columns]

# %%
# Create State Dataframe to store statusID and name
state_df = generator_full_df[["stateid", "stateName"]].drop_duplicates(ignore_index=True)
state_df = state_df.set_index("stateid")
state_df
# Out:
#         stateName
# stateid
# TX          Texas

# %%
# Create Status Dataframe to store statusID and description
status_df = generator_full_df[["status", "statusDescription"]].drop_duplicates(ignore_index=True)
status_df = status_df.set_index("status")
status_df
# Out:
#                                         statusDescription
# status
# OP                                              Operating
# SB      Standby/Backup: available for service but not ...
# OS      Out of service and NOT expected to return to s...
# OA      Out of service but expected to return to servi...

# %%
# Create Energy Source Dataframe to store statusID and description
sources_df = generator_full_df[["energy_source_code", "energy-source-desc"]].drop_duplicates(ignore_index=True).sort_values(by=["energy_source_code"])
sources_df = sources_df.set_index("energy_source_code")
sources_df
# Out:
#                                      energy-source-desc
# energy_source_code
# AB                               Agriculture Byproducts
# BFG                                   Blast-Furnace Gas
# BLQ                                        Black Liquor
# DFO                                  Disillate Fuel Oil
# LFG                                        Landfill Gas
# LIG                                             Lignite
# MWH                 Electricity used for energy storage
# NG                                          Natural Gas
# NUC                                             Nuclear
# OG                                            Other Gas
# PC                                       Petroleum Coke
# PUR                                     Purchased Steam
# RC                                         Refined Coal
# SUB                                  Subbituminous Coal
# SUN                                               Solar
# WAT                                               Water
# WDS                                   Wood Waste Solids
# WH                                           Waste Heat
# WND                                                Wind

# %%
# Confirm whether this column is blank for all rows - if blank for all, can delete from dataframe
balancing_authorities = generator_full_df["balancing-authority-name"].unique()
balancing_authorities
# Out:
# array([None, 'Electric Reliability Council of Texas, Inc.',
#        'Midcontinent Independent Transmission System Operator, Inc..',
#        'Southwest Power Pool', 'El Paso Electric Company',
#        'Public Service Company of New Mexico'], dtype=object)

# %%
# Drop columns to create summarized generator dataframe
generators_clean_df = generator_full_df.drop(columns=["stateName", "sectorName", "entityName", "plantName", "statusDescription", "energy-source-desc", "unit"])
generators_clean_df.head()
# Out:
#     period stateid          sector  entityid  plantid generatorid  \
# 0  2023-01      TX     ipp-non-chp       313    55139        CTG1
# 1  2023-01      TX     ipp-non-chp       313    55139        CTG2
# 2  2023-01      TX     ipp-non-chp       313    55139          ST
# 3  2023-01      TX  industrial-chp       327    10298         GT1
# 4  2023-01      TX  industrial-chp       327    10298         GT2
#
#                              technology energy_source_code prime_mover_code  \
# 0      Natural Gas Fired Combined Cycle                 NG               CT
# 1      Natural Gas Fired Combined Cycle                 NG               CT
# 2      Natural Gas Fired Combined Cycle                 NG               CA
# 3  Natural Gas Fired Combustion Turbine                 NG               GT
# 4  Natural Gas Fired Combustion Turbine                 NG               GT
#
#   balancing_authority_code balancing-authority-name status  latitude  \
# 0                     None                     None     OP  32.33422
# 1                     None                     None     OP  32.33422
# 2                     None                     None     OP  32.33422
# 3                     None                     None     OP  29.62250
# 4                     None                     None     OP  29.62250
#
#    longitude
# 0 -97.731686
# 1 -97.731686
# 2 -97.731686
# 3 -95.045800
# 4 -95.045800

# %%
# Export all Dataframes to CSV for importing into SQL
sector_df.to_csv("Output/Sector_DF.csv")
entity_df_clean.to_csv("Output/Entity_DF.csv")
plant_df_clean.to_csv("Output/Plant_DF.csv")
status_df.to_csv("Output/Status_DF.csv")
state_df.to_csv("Output/States_DF.csv")
sources_df.to_csv("Output/Energy_Sources_DF.csv")
generators_clean_df.to_csv("Output/Generators_DF.csv")

# %% [markdown]
# ### Price Details API Pull - January 2020 to January 2023

# %%
# Price Details
url = f"https://api.eia.gov/v2/natural-gas/pri/sum/data/?api_key={api_key}&frequency=monthly&data[0]=value&facets[duoarea][]=STX&start=2020-01&end=2023-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
response = requests.get(url)
response.raise_for_status()

# Retrieve the data
price_data = response.json()
pprint.pprint(price_data)
# Out:
# {'apiVersion': '2.1.4',
#  'request': {'command': '/v2/natural-gas/pri/sum/data/',
#              'params': {'api_key': 'msLbwqq4bJqp1UAFRX7ulbpXsXoju1uJalc0DDJz',
#                         'data': ['value'],
#                         'end': '2023-01',
#                         'facets': {'duoarea': ['STX']},
#                         'frequency': 'monthly',
#                         'length': 5000,
#                         'offset': 0,
#                         'sort': [{'column': 'period', 'direction': 'desc'}],
#                         'start': '2020-01'}},
#  'response': {'data': [{'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 5.34},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 16.01},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 28.6},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 75.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 12.33},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 6.82},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-12',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 6.52},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 11.96},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 29.8},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 5.04},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 17.1},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 73},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 4.74},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-11',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 6.05},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.8},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 5.24},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 29.3},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 65.4},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 6.34},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 5.82},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 26.54},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-10',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 14.02},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 30.5},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 9.27},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 31.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 15.15},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 9.26},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.1},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 7.63},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-09',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 60.4},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 14.93},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 8.52},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 33.69},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 10.07},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 98.6},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 30.1},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-08',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 60.2},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 13.34},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 7.12},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 30.8},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 10.59},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 7.18},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 62.2},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 98.2},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-07',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 29.68},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 30.7},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 9.36},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 27.75},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 62.1},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 7.61},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 9.7},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 13.46},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-06',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 13.03},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 7.91},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 7.8},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 30.4},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 64.5},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 8.58},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 25.12},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-05',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.2},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-04',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 17.42},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2022-04',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
# ...
#                         'units': '$/MCF',
#                         'value': 9.27},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-03',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 5.65},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-03',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 70.5},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-03',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 2.04},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-03',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-03',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 29.2},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-03',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 2.43},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 5.22},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 99.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 2.31},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 8.07},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 76.2},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 28.9},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 1.86},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-02',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 2.1},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'VRX',
#                         'process-name': 'Percent Sold to The Commercial Sector',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'NA1504_STX_4',
#                         'series-description': 'Texas Natural Gas % of Total '
#                                               'Residential - Sales (%)',
#                         'units': '%',
#                         'value': 100},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'PCS',
#                         'process-name': 'Price Delivered to Commercial Sectors',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX3',
#                         'series-description': 'Texas Price of Natural Gas Sold '
#                                               'to Commercial Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 5.57},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'VFA',
#                         'process-name': '% of Industrial Consumers - Sales',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX4',
#                         'series-description': 'Percent of Industrial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 29.8},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'PIN',
#                         'process-name': 'Industrial Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3035TX3',
#                         'series-description': 'Texas Natural Gas Industrial '
#                                               'Price (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 2.32},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'PRS',
#                         'process-name': 'Price Delivered to Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3010TX3',
#                         'series-description': 'Texas Price of Natural Gas '
#                                               'Delivered to Residential '
#                                               'Consumers (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 8.26},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'PEU',
#                         'process-name': 'Electric Power Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3045TX3',
#                         'series-description': 'Texas Natural Gas Price Sold to '
#                                               'Electric Power Consumers '
#                                               '(Dollars per Thousand Cubic '
#                                               'Feet)',
#                         'units': '$/MCF',
#                         'value': 1.93},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'PG1',
#                         'process-name': 'City Gate Price',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3050TX3',
#                         'series-description': 'Natural Gas Citygate Price in '
#                                               'Texas (Dollars per Thousand '
#                                               'Cubic Feet)',
#                         'units': '$/MCF',
#                         'value': 2.55},
#                        {'area-name': 'TEXAS',
#                         'duoarea': 'STX',
#                         'period': '2020-01',
#                         'process': 'VFC',
#                         'process-name': 'Percent Sold to The Residential '
#                                         'Consumers',
#                         'product': 'EPG0',
#                         'product-name': 'Natural Gas',
#                         'series': 'N3020TX4',
#                         'series-description': 'Percent of Commercial Natural '
#                                               'Gas Deliveries in Texas '
#                                               'Represented by the Price (%)',
#                         'units': '%',
#                         'value': 78.7}],
#               'dateFormat': 'YYYY-MM',
#               'frequency': 'monthly',
#               'total': 576}}

# %%
# Create Dataframe of Price data
price_data_df = pd.json_normalize(price_data["response"]["data"])
print("Rows in Dataframe: ", len(price_data_df))
price_data_df.head()
# Note there are fewer rows than it states on the API dashboard because the final 2 pages of API results are blank
# Out:
# Rows in Dataframe:  288
#     period duoarea area-name product product-name process  \
# 0  2022-12     STX     TEXAS    EPG0  Natural Gas     PEU
# 1  2022-12     STX     TEXAS    EPG0  Natural Gas     PRS
# 2  2022-12     STX     TEXAS    EPG0  Natural Gas     VRX
# 3  2022-12     STX     TEXAS    EPG0  Natural Gas     VFA
# 4  2022-12     STX     TEXAS    EPG0  Natural Gas     VFC
#
#                                 process-name        series  \
# 0                       Electric Power Price      N3045TX3
# 1   Price Delivered to Residential Consumers      N3010TX3
# 2      Percent Sold to The Commercial Sector  NA1504_STX_4
# 3          % of Industrial Consumers - Sales      N3035TX4
# 4  Percent Sold to The Residential Consumers      N3020TX4
#
#                                   series-description  value  units
# 0  Texas Natural Gas Price Sold to Electric Power...   5.34  $/MCF
# 1  Texas Price of Natural Gas Delivered to Reside...  16.01  $/MCF
# 2  Texas Natural Gas % of Total Residential - Sal...  99.90      %
# 3  Percent of Industrial Natural Gas Deliveries i...  28.60      %
# 4  Percent of Commercial Natural Gas Deliveries i...  75.90      %

# %%
# Create Series Dataframe to store seriesID and description
series_df = price_data_df[["series", "series-description"]].drop_duplicates(ignore_index=True)
series_df = series_df.set_index("series")
series_df
# Out:
#                                              series-description
# series
# N3045TX3      Texas Natural Gas Price Sold to Electric Power...
# N3010TX3      Texas Price of Natural Gas Delivered to Reside...
# NA1504_STX_4  Texas Natural Gas % of Total Residential - Sal...
# N3035TX4      Percent of Industrial Natural Gas Deliveries i...
# N3020TX4      Percent of Commercial Natural Gas Deliveries i...
# N3020TX3      Texas Price of Natural Gas Sold to Commercial ...
# N3050TX3      Natural Gas Citygate Price in Texas (Dollars p...
# N3035TX3      Texas Natural Gas Industrial Price (Dollars pe...

# %%
# Create Process Dataframe to store processID and name
process_df = price_data_df[["process", "process-name"]].drop_duplicates(ignore_index=True)
process_df = process_df.set_index("process")
process_df
# Out:
#                                       process-name
# process
# PEU                           Electric Power Price
# PRS       Price Delivered to Residential Consumers
# VRX          Percent Sold to The Commercial Sector
# VFA              % of Industrial Consumers - Sales
# VFC      Percent Sold to The Residential Consumers
# PCS          Price Delivered to Commercial Sectors
# PG1                                City Gate Price
# PIN                               Industrial Price

# %%
# Drop duplicate or irrelevant columns to create clean price dataframe
price_df_clean = price_data_df.drop(columns=["duoarea", "product", "process-name", "series-description"])
price_df_clean.head()
# Out:
#     period area-name product-name process        series  value  units
# 0  2022-12     TEXAS  Natural Gas     PEU      N3045TX3   5.34  $/MCF
# 1  2022-12     TEXAS  Natural Gas     PRS      N3010TX3  16.01  $/MCF
# 2  2022-12     TEXAS  Natural Gas     VRX  NA1504_STX_4  99.90      %
# 3  2022-12     TEXAS  Natural Gas     VFA      N3035TX4  28.60      %
# 4  2022-12     TEXAS  Natural Gas     VFC      N3020TX4  75.90      %

# %%
# Drop rows with % as unit, as we're only looking at price data, and delete blank rows
natural_gas_price_data_df = price_df_clean[price_df_clean.units != "%"].dropna()
natural_gas_price_data_df
# Out:
#       period area-name product-name process    series  value  units
# 0    2022-12     TEXAS  Natural Gas     PEU  N3045TX3   5.34  $/MCF
# 1    2022-12     TEXAS  Natural Gas     PRS  N3010TX3  16.01  $/MCF
# 5    2022-12     TEXAS  Natural Gas     PCS  N3020TX3  12.33  $/MCF
# 6    2022-12     TEXAS  Natural Gas     PG1  N3050TX3   6.82  $/MCF
# 7    2022-12     TEXAS  Natural Gas     PIN  N3035TX3   6.52  $/MCF
# ..       ...       ...          ...     ...       ...    ...    ...
# 281  2020-01     TEXAS  Natural Gas     PCS  N3020TX3   5.57  $/MCF
# 283  2020-01     TEXAS  Natural Gas     PIN  N3035TX3   2.32  $/MCF
# 284  2020-01     TEXAS  Natural Gas     PRS  N3010TX3   8.26  $/MCF
# 285  2020-01     TEXAS  Natural Gas     PEU  N3045TX3   1.93  $/MCF
# 286  2020-01     TEXAS  Natural Gas     PG1  N3050TX3   2.55  $/MCF
#
# [179 rows x 7 columns]

# %%
natural_gas_price_data_df.loc[natural_gas_price_data_df["area-name"] == "TEXAS", "area-name"] = "TX"
natural_gas_price_data_df
# Out:
#       period area-name product-name process    series  value  units
# 0    2022-12        TX  Natural Gas     PEU  N3045TX3   5.34  $/MCF
# 1    2022-12        TX  Natural Gas     PRS  N3010TX3  16.01  $/MCF
# 5    2022-12        TX  Natural Gas     PCS  N3020TX3  12.33  $/MCF
# 6    2022-12        TX  Natural Gas     PG1  N3050TX3   6.82  $/MCF
# 7    2022-12        TX  Natural Gas     PIN  N3035TX3   6.52  $/MCF
# ..       ...       ...          ...     ...       ...    ...    ...
# 281  2020-01        TX  Natural Gas     PCS  N3020TX3   5.57  $/MCF
# 283  2020-01        TX  Natural Gas     PIN  N3035TX3   2.32  $/MCF
# 284  2020-01        TX  Natural Gas     PRS  N3010TX3   8.26  $/MCF
# 285  2020-01        TX  Natural Gas     PEU  N3045TX3   1.93  $/MCF
# 286  2020-01        TX  Natural Gas     PG1  N3050TX3   2.55  $/MCF
#
# [179 rows x 7 columns]

# %%
# Export all Dataframes to CSV for importing into SQL
process_df.to_csv("Output/Processes_DF.csv")
natural_gas_price_data_df.to_csv("Output/Energy_Prices_DF.csv")
price_data_df.to_csv("Output/Prices_Full_report.csv")

# %%
# Create Chart of Prices detail by sector
prices_df = natural_gas_price_data_df
PEU_price = prices_df[prices_df['process'] == 'PEU']
PRS_price = prices_df[prices_df['process'] == 'PRS']
PCS_price = prices_df[prices_df['process'] == 'PCS']
PG1_price = prices_df[prices_df['process'] == 'PG1']
PIN_price = prices_df[prices_df['process'] == 'PIN']

PEU_price = PEU_price.sort_values('period')
PRS_price = PRS_price.sort_values('period')
PCS_price = PCS_price.sort_values('period')
PG1_price = PG1_price.sort_values('period')
PIN_price = PIN_price.sort_values('period')

plt.figure(figsize=(10, 6))
plt.plot(PEU_price['period'], PEU_price['value'], label='Electric Power Price')
plt.plot(PRS_price['period'], PRS_price['value'], label='Price Delivered to Residential Consumers')
plt.plot(PCS_price['period'], PCS_price['value'], label='Price Delivered to Commercial Sectors')
plt.plot(PG1_price['period'], PG1_price['value'], label='City Gate Price')
plt.plot(PIN_price['period'], PIN_price['value'], label='Industrial Price')

plt.xlabel('Period')
plt.ylabel('Price Values ($/MCF)')
plt.title('Natural Gas Prices For State Texas(JAN2020-JAN2023)')
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Industrial, Residential, Commerical, and CO2 Emissions API Pull - January 2020 to January 2023

# %%
# Define the API key and endpoint URL
api_key = EIA_api_key

# URL endpoint
url = f'https://api.eia.gov/v2/total-energy/data/?api_key={api_key}&frequency=monthly&data[0]=value&facets[msn][]=TXCCBUS&facets[msn][]=TXEIEUS&facets[msn][]=TXICBUS&facets[msn][]=TXRCBUS&start=2020-01&end=2023-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
try:
    # Send the API request
    response = requests.get(url)
    response.raise_for_status()

    # Retrieve the data
    data = response.json()

    # Process the data as needed
    if "data" in data["response"]:
        # Extract the data
        pprint.pprint(data)
        
    else:
        print("No data available.")
except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
# Out:
# {'apiVersion': '2.1.4',
#  'request': {'command': '/v2/total-energy/data/',
#              'params': {'api_key': 'msLbwqq4bJqp1UAFRX7ulbpXsXoju1uJalc0DDJz',
#                         'data': ['value'],
#                         'end': '2023-01',
#                         'facets': {'msn': ['TXCCBUS',
#                                            'TXEIEUS',
#                                            'TXICBUS',
#                                            'TXRCBUS']},
#                         'frequency': 'monthly',
#                         'length': 5000,
#                         'offset': 0,
#                         'sort': [{'column': 'period', 'direction': 'desc'}],
#                         'start': '2020-01'}},
#  'response': {'data': [{'msn': 'TXCCBUS',
#                         'period': '2023-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 621.73},
#                        {'msn': 'TXEIEUS',
#                         'period': '2023-01',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 117.289},
#                        {'msn': 'TXICBUS',
#                         'period': '2023-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1953.793},
#                        {'msn': 'TXRCBUS',
#                         'period': '2023-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1045.863},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1863.02},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1072.433},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 634.577},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-12',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 133.744},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 473.162},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 701.878},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1959.514},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-11',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 109.755},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 330.13},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 402.348},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-10',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 110.759},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1963.464},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 242.726},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 245.328},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1902.072},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-09',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 130.619},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 229.952},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1966.07},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 226.178},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-08',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 164.227},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1970.161},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 238.059},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 234.841},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-07',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 167.55},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1895.275},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 257.783},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 242.322},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-06',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 139.866},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 286.245},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 351.462},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1875.529},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-05',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 115.77},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1882.9},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 562.086},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 387.065},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-04',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 98.251},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 520.119},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 801.078},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1995.185},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-03',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 106.405},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 611.202},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1034.126},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-02',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 118.466},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1848.635},
#                        {'msn': 'TXCCBUS',
#                         'period': '2022-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 702.927},
#                        {'msn': 'TXICBUS',
#                         'period': '2022-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 2060.225},
#                        {'msn': 'TXRCBUS',
#                         'period': '2022-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1217.697},
#                        {'msn': 'TXEIEUS',
#                         'period': '2022-01',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 143.813},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 537.006},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 876.67},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 2010.912},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-12',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 113.129},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 455.939},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 658.958},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1931.111},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-11',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 109.493},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 301.648},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 333.096},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-10',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 118.184},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1948.29},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 243.184},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 235.863},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1868.884},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-09',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 136.815},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 229.639},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1952.382},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 215.097},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-08',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 173.636},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 233.712},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 226.341},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1902.92},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-07',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 172.241},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1879.563},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 250.305},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 238.091},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-06',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 148.549},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 285.755},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 359.032},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1921.45},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-05',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 111.255},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1889.505},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 501.189},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 356.864},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-04',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 98.07},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 488.179},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 772.907},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1893.811},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-03',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 105.397},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 638.106},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1110.143},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-02',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 132.683},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1608.734},
#                        {'msn': 'TXCCBUS',
#                         'period': '2021-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 639.484},
#                        {'msn': 'TXICBUS',
#                         'period': '2021-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 2021.563},
#                        {'msn': 'TXRCBUS',
#                         'period': '2021-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1128.654},
#                        {'msn': 'TXEIEUS',
#                         'period': '2021-01',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 131.639},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 2006.327},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1009.398},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-12',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 579.865},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-12',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 129.53},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 398.324},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 598.95},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-11',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1904.864},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-11',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 106.332},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 306.716},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 379.095},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-10',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 115.043},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-10',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1886.104},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 232.711},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 241.42},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-09',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1785.222},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-09',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 127.415},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 214.68},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1845.961},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-08',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 214.021},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-08',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 163.421},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1800.216},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 225.971},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-07',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 213.97},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-07',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 166.135},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1686.459},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 252.239},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-06',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 220.331},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-06',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 125.497},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 263.144},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 383.995},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-05',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1684.977},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-05',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 96.374},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1616.772},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 537.81},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-04',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 334.965},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-04',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 87.316},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 454.508},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 705.753},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-03',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1941.479},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-03',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 103.382},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 572.812},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 934.462},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-02',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 108.891},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-02',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1888.423},
#                        {'msn': 'TXCCBUS',
#                         'period': '2020-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Commercial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 627.259},
#                        {'msn': 'TXICBUS',
#                         'period': '2020-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Industrial Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 2013.471},
#                        {'msn': 'TXEIEUS',
#                         'period': '2020-01',
#                         'seriesDescription': 'Total Energy Electric Power '
#                                              'Sector CO2 Emissions in Million '
#                                              'Metric Tons of Carbon Dioxide',
#                         'unit': 'Million Metric Tons of Carbon Dioxide',
#                         'value': 120.822},
#                        {'msn': 'TXRCBUS',
#                         'period': '2020-01',
#                         'seriesDescription': 'Total Primary Energy Consumed by '
#                                              'the Residential Sector in '
#                                              'Trillion Btu',
#                         'unit': 'Trillion Btu',
#                         'value': 1043.146}],
#               'dateFormat': 'YYYY-MM',
#               'description': 'These data represent the most recent '
#                              'comprehensive energy statistics integrated '
#                              'across all energy sources.  The data includes '
#                              'total energy production, consumption, stocks, '
#                              'and trade; energy prices; overviews of '
#                              'petroleum, natural gas, coal, electricity, '
#                              'nuclear energy, renewable energy, and carbon '
#                              'dioxide emissions; and data unit conversions '
#                              'values.  Source: '
#                              'https://www.eia.gov/totalenergy/data/monthly/pdf/mer_a_doc.pdf  '
#                              'Report:  MER '
#                              '(https://www.eia.gov/totalenergy/data/monthly/)',
#               'frequency': 'monthly',
#               'total': 148}}

# %%
# Convert JSON file to Pandas Dataframe and confirm # of rows matches original file
data_df = pd.json_normalize(data["response"]["data"])
print("Rows in Dataframe: ", len(data_df))
data_df
# Out:
# Rows in Dataframe:  148
#       period      msn                                  seriesDescription  \
# 0    2023-01  TXCCBUS  Total Primary Energy Consumed by the Commercia...
# 1    2023-01  TXEIEUS  Total Energy Electric Power Sector CO2 Emissio...
# 2    2023-01  TXICBUS  Total Primary Energy Consumed by the Industria...
# 3    2023-01  TXRCBUS  Total Primary Energy Consumed by the Residenti...
# 4    2022-12  TXICBUS  Total Primary Energy Consumed by the Industria...
# ..       ...      ...                                                ...
# 143  2020-02  TXICBUS  Total Primary Energy Consumed by the Industria...
# 144  2020-01  TXCCBUS  Total Primary Energy Consumed by the Commercia...
# 145  2020-01  TXICBUS  Total Primary Energy Consumed by the Industria...
# 146  2020-01  TXEIEUS  Total Energy Electric Power Sector CO2 Emissio...
# 147  2020-01  TXRCBUS  Total Primary Energy Consumed by the Residenti...
#
#         value                                   unit
# 0     621.730                           Trillion Btu
# 1     117.289  Million Metric Tons of Carbon Dioxide
# 2    1953.793                           Trillion Btu
# 3    1045.863                           Trillion Btu
# 4    1863.020                           Trillion Btu
# ..        ...                                    ...
# 143  1888.423                           Trillion Btu
# 144   627.259                           Trillion Btu
# 145  2013.471                           Trillion Btu
# 146   120.822  Million Metric Tons of Carbon Dioxide
# 147  1043.146                           Trillion Btu
#
# [148 rows x 5 columns]

# %%
con_series_df = data_df[["msn", "seriesDescription"]].drop_duplicates(ignore_index=True)
con_series_df = con_series_df.rename(columns={"msn": "series", "seriesDescription": "series-description"}).set_index("series")
con_series_df
# Out:
#                                         series-description
# series
# TXCCBUS  Total Primary Energy Consumed by the Commercia...
# TXEIEUS  Total Energy Electric Power Sector CO2 Emissio...
# TXICBUS  Total Primary Energy Consumed by the Industria...
# TXRCBUS  Total Primary Energy Consumed by the Residenti...

# %%
larger_series_df = pd.merge(series_df, con_series_df, how="outer", on=["series", "series-description"])
larger_series_df
# Out:
#                                              series-description
# series
# N3045TX3      Texas Natural Gas Price Sold to Electric Power...
# N3010TX3      Texas Price of Natural Gas Delivered to Reside...
# NA1504_STX_4  Texas Natural Gas % of Total Residential - Sal...
# N3035TX4      Percent of Industrial Natural Gas Deliveries i...
# N3020TX4      Percent of Commercial Natural Gas Deliveries i...
# N3020TX3      Texas Price of Natural Gas Sold to Commercial ...
# N3050TX3      Natural Gas Citygate Price in Texas (Dollars p...
# N3035TX3      Texas Natural Gas Industrial Price (Dollars pe...
# TXCCBUS       Total Primary Energy Consumed by the Commercia...
# TXEIEUS       Total Energy Electric Power Sector CO2 Emissio...
# TXICBUS       Total Primary Energy Consumed by the Industria...
# TXRCBUS       Total Primary Energy Consumed by the Residenti...

# %%
# Drop now-redundant column
data_df = data_df.drop(columns=["seriesDescription"])
data_df
# Out:
#       period      msn     value                                   unit
# 0    2023-01  TXCCBUS   621.730                           Trillion Btu
# 1    2023-01  TXEIEUS   117.289  Million Metric Tons of Carbon Dioxide
# 2    2023-01  TXICBUS  1953.793                           Trillion Btu
# 3    2023-01  TXRCBUS  1045.863                           Trillion Btu
# 4    2022-12  TXICBUS  1863.020                           Trillion Btu
# ..       ...      ...       ...                                    ...
# 143  2020-02  TXICBUS  1888.423                           Trillion Btu
# 144  2020-01  TXCCBUS   627.259                           Trillion Btu
# 145  2020-01  TXICBUS  2013.471                           Trillion Btu
# 146  2020-01  TXEIEUS   120.822  Million Metric Tons of Carbon Dioxide
# 147  2020-01  TXRCBUS  1043.146                           Trillion Btu
#
# [148 rows x 4 columns]

# %%
# Export Dataframe to CSV for importing into SQL
data_df.to_csv("Output/Consumption_and_CO2.csv")

# %%
# Create separate dataframes for each MSN (Unique series identifier)
dataframes = {}

# Get unique values from the 'msn' column
unique_msn = data_df['msn'].unique()

# Split the data based on unique 'msn' values
for msn in unique_msn:
    dataframes[msn] = data_df[data_df['msn'] == msn].copy()

# Access the individual dataframes using the 'msn' as the key
df_txicbus = dataframes['TXICBUS']
df_txrcbus = dataframes['TXRCBUS']
df_txccbus = dataframes['TXCCBUS']
df_txeieus = dataframes['TXEIEUS']

# %%
# Char of Total Primary Energy Consumption by Sector
df = data_df
# Filter data for each category
commercial_data = df[df['msn'] == 'TXCCBUS']
industrial_data = df[df['msn'] == 'TXICBUS']
residential_data = df[df['msn'] == 'TXRCBUS']
co2_emissions_data = df[df['msn'] == 'TXEIEUS']

# Sort data by 'period' column in ascending order
commercial_data = commercial_data.sort_values('period')
industrial_data = industrial_data.sort_values('period')
residential_data = residential_data.sort_values('period')
co2_emissions_data = co2_emissions_data.sort_values('period')

# Line plot of Total Primary Energy Consumption by Commercial, Industrial, and Residential sectors over time
plt.figure(figsize=(10, 6))
plt.plot(commercial_data['period'], commercial_data['value'], label='Commercial')
plt.plot(industrial_data['period'], industrial_data['value'], label='Industrial')
plt.plot(residential_data['period'], residential_data['value'], label='Residential')
plt.xlabel('Period')
plt.ylabel('Total Primary Energy Consumption (Trillion Btu)')
plt.title('Total Primary Energy Consumption by Sector')
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
plt.savefig('Images/energy_consumption.png', dpi=300)

# %%
# Bar plot of Total Energy Electric Power Sector CO2 Emissions over time
plt.figure(figsize=(10, 6))
plt.bar(co2_emissions_data['period'], co2_emissions_data['value'])
plt.xlabel('Period')
plt.ylabel('CO2 Emissions (Million Metric Tons of CO2)')
plt.title('Total Energy Electric Power Sector CO2 Emissions')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.savefig('Images/co2_emissions.png', dpi=300)

# %% [markdown]
# ### Net Power Consumption and Generation API Pull - January 2020 to January 2023

# %%
# URL endpoint
url = f'https://api.eia.gov/v2/steo/data/?api_key={api_key}&frequency=monthly&data[0]=value&facets[seriesId][]=CLEPCNS_TX&facets[seriesId][]=CLEPGEN_TX&facets[seriesId][]=NGEPCNS_TX&facets[seriesId][]=NGEPGEN_TX&facets[seriesId][]=PAEPCNS_TX&facets[seriesId][]=PAEPGEN_TX&start=2020-01&end=2023-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'
try:
    # Send the API request
    response = requests.get(url)
    response.raise_for_status()

    # Retrieve the data
    data = response.json()

    # Process the data as needed
    if "data" in data["response"]:
        # Extract the generator counts by location and energy source
        generator_counts = data["response"]["data"]
        pprint.pprint(data)
        
    else:
        print("No data available.")
except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
# Out:
# {'apiVersion': '2.1.4',
#  'request': {'command': '/v2/steo/data/',
#              'params': {'api_key': 'msLbwqq4bJqp1UAFRX7ulbpXsXoju1uJalc0DDJz',
#                         'data': ['value'],
#                         'end': '2023-01',
#                         'facets': {'seriesId': ['CLEPCNS_TX',
#                                                 'CLEPGEN_TX',
#                                                 'NGEPCNS_TX',
#                                                 'NGEPGEN_TX',
#                                                 'PAEPCNS_TX',
#                                                 'PAEPGEN_TX']},
#                         'frequency': 'monthly',
#                         'length': 5000,
#                         'offset': 0,
#                         'sort': [{'column': 'period', 'direction': 'desc'}],
#                         'start': '2020-01'}},
#  'response': {'data': [{'period': '2023-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 2542.258},
#                        {'period': '2023-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.008989852},
#                        {'period': '2023-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 3.350762366},
#                        {'period': '2023-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 12.517534399},
#                        {'period': '2023-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 103.396003},
#                        {'period': '2023-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 22.669},
#                        {'period': '2022-12',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3995.628},
#                        {'period': '2022-12',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.09805635},
#                        {'period': '2022-12',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 227.992},
#                        {'period': '2022-12',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 14.586473427},
#                        {'period': '2022-12',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 117.037589},
#                        {'period': '2022-12',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.455245849},
#                        {'period': '2022-11',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 99.396507},
#                        {'period': '2022-11',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 12.046655903},
#                        {'period': '2022-11',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 28.747},
#                        {'period': '2022-11',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.014218571},
#                        {'period': '2022-11',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3886.164},
#                        {'period': '2022-11',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.504823316},
#                        {'period': '2022-10',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3940.921},
#                        {'period': '2022-10',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.01569722},
#                        {'period': '2022-10',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 37.06},
#                        {'period': '2022-10',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 14.27722329},
#                        {'period': '2022-10',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 116.243914},
#                        {'period': '2022-10',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.603011948},
#                        {'period': '2022-09',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4426.88},
#                        {'period': '2022-09',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.011193487},
#                        {'period': '2022-09',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 24.408},
#                        {'period': '2022-09',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 19.232498057},
#                        {'period': '2022-09',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 152.357819},
#                        {'period': '2022-09',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 6.303659776},
#                        {'period': '2022-08',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 183.737182},
#                        {'period': '2022-08',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 22.87411766},
#                        {'period': '2022-08',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 23.844},
#                        {'period': '2022-08',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.01069355},
#                        {'period': '2022-08',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4707.024},
#                        {'period': '2022-08',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 6.801359149},
#                        {'period': '2022-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.011445227},
#                        {'period': '2022-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4802.044},
#                        {'period': '2022-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 24.557},
#                        {'period': '2022-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 22.609434374},
#                        {'period': '2022-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 183.095895},
#                        {'period': '2022-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 7.068470955},
#                        {'period': '2022-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4540.143},
#                        {'period': '2022-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.009210472},
#                        {'period': '2022-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 21.145},
#                        {'period': '2022-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 18.802036127},
#                        {'period': '2022-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 153.258101},
#                        {'period': '2022-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 6.645845238},
#                        {'period': '2022-05',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.006266145},
#                        {'period': '2022-05',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3639.405},
#                        {'period': '2022-05',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 14.374},
#                        {'period': '2022-05',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.092948441},
#                        {'period': '2022-05',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 125.157331},
#                        {'period': '2022-05',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 15.023112657},
#                        {'period': '2022-04',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3528.968},
#                        {'period': '2022-04',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.004820163},
#                        {'period': '2022-04',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 12.044},
#                        {'period': '2022-04',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 9.00984863},
#                        {'period': '2022-04',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 78.418461},
#                        {'period': '2022-04',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.071148175},
#                        {'period': '2022-03',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3451.35},
#                        {'period': '2022-03',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.006549567},
#                        {'period': '2022-03',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 75.209946},
#                        {'period': '2022-03',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 8.531399728},
#                        {'period': '2022-03',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 13.313},
#                        {'period': '2022-03',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.146731461},
#                        {'period': '2022-02',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 97.483617},
#                        {'period': '2022-02',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.978240458},
#                        {'period': '2022-02',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4157.795},
#                        {'period': '2022-02',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.018469559},
#                        {'period': '2022-02',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 41.243},
#                        {'period': '2022-02',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 11.752305181},
#                        {'period': '2022-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4468.262},
#                        {'period': '2022-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.024099495},
#                        {'period': '2022-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 6.545819382},
#                        {'period': '2022-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 13.132743889},
#                        {'period': '2022-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 107.535637},
#                        {'period': '2022-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 51.731},
#                        {'period': '2021-12',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.005182439},
#                        {'period': '2021-12',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3935.291},
#                        {'period': '2021-12',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 10.99},
#                        {'period': '2021-12',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 10.40138046},
#                        {'period': '2021-12',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 84.96975},
#                        {'period': '2021-12',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.393876372},
#                        {'period': '2021-11',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3616.039},
#                        {'period': '2021-11',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.019232065},
#                        {'period': '2021-11',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 36.962},
#                        {'period': '2021-11',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 9.873711519},
#                        {'period': '2021-11',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 82.872649},
#                        {'period': '2021-11',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.121430202},
#                        {'period': '2021-10',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.007207524},
#                        {'period': '2021-10',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4137.719},
#                        {'period': '2021-10',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 15.941},
#                        {'period': '2021-10',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.949044058},
#                        {'period': '2021-10',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 115.99062},
#                        {'period': '2021-10',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 13.964897335},
#                        {'period': '2021-09',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 4610.037},
#                        {'period': '2021-09',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.008984297},
#                        {'period': '2021-09',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 18.492},
#                        {'period': '2021-09',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 17.17023791},
#                        {'period': '2021-09',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 139.699295},
#                        {'period': '2021-09',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 6.639198678},
#                        {'period': '2021-08',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 5100.051},
#                        {'period': '2021-08',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.003479871},
#                        {'period': '2021-08',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 167.39061},
#                        {'period': '2021-08',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 20.476046293},
#                        {'period': '2021-08',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 7.382},
#                        {'period': '2021-08',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 7.450635036},
#                        {'period': '2021-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 5447.657},
#                        {'period': '2021-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.003017247},
#                        {'period': '2021-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 6.311},
#                        {'period': '2021-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 20.167196766},
#                        {'period': '2021-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 164.703596},
#                        {'period': '2021-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 7.934833092},
#                        {'period': '2021-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 144.567998},
#                        {'period': '2021-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 17.550486639},
#                        {'period': '2021-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
# ...
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 21.439225696},
#                        {'period': '2020-07',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 174.440063},
#                        {'period': '2020-07',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 6.348566553},
#                        {'period': '2020-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3954.98},
#                        {'period': '2020-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.002656115},
#                        {'period': '2020-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 5.209},
#                        {'period': '2020-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 16.651489585},
#                        {'period': '2020-06',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 135.032304},
#                        {'period': '2020-06',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 5.501823001},
#                        {'period': '2020-05',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.003183304},
#                        {'period': '2020-05',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3592.526},
#                        {'period': '2020-05',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 6.277},
#                        {'period': '2020-05',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 4.898149216},
#                        {'period': '2020-05',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 114.630016},
#                        {'period': '2020-05',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 14.05938931},
#                        {'period': '2020-04',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3404.71},
#                        {'period': '2020-04',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.004323043},
#                        {'period': '2020-04',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 8.943},
#                        {'period': '2020-04',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 10.997354784},
#                        {'period': '2020-04',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 90.934755},
#                        {'period': '2020-04',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 4.863269918},
#                        {'period': '2020-03',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 2958.549},
#                        {'period': '2020-03',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.002392061},
#                        {'period': '2020-03',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 100.81033},
#                        {'period': '2020-03',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 12.279991759},
#                        {'period': '2020-03',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 4.722},
#                        {'period': '2020-03',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 4.2851941},
#                        {'period': '2020-02',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 99.341021},
#                        {'period': '2020-02',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 3.947824918},
#                        {'period': '2020-02',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 2911.195},
#                        {'period': '2020-02',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.005600183},
#                        {'period': '2020-02',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 10.947},
#                        {'period': '2020-02',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 12.468100158},
#                        {'period': '2020-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPCNS_TX',
#                         'unit': 'thousand short tons',
#                         'value': 3225.376},
#                        {'period': '2020-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from coal, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'CLEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 4.36457469},
#                        {'period': '2020-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 0.002526854},
#                        {'period': '2020-01',
#                         'seriesDescription': 'Electric power sector net '
#                                              'generation from natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPGEN_TX',
#                         'unit': 'billion kilowatthours',
#                         'value': 12.775475621},
#                        {'period': '2020-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of petroleum, Texas '
#                                              '(ERCOT)',
#                         'seriesId': 'PAEPCNS_TX',
#                         'unit': 'thousand barrels',
#                         'value': 4.997},
#                        {'period': '2020-01',
#                         'seriesDescription': 'Electric power sector  '
#                                              'consumption of natural gas, '
#                                              'Texas (ERCOT)',
#                         'seriesId': 'NGEPCNS_TX',
#                         'unit': 'billion cubic feet',
#                         'value': 101.322595}],
#               'dateFormat': 'YYYY-MM',
#               'description': 'Monthly short term (18 month) projections using '
#                              'STEO model.  \r\n'
#                              '        Report and interactive projection data '
#                              'browser:  STEO (www.eia.gov/steo/)',
#               'frequency': 'monthly',
#               'total': 222}}

# %%
# Convert JSON file to Pandas Dataframe and confirm # of rows matches original file
gen_data_df = pd.json_normalize(data["response"]["data"])
print("Rows in Dataframe: ", len(gen_data_df))
gen_data_df
# Out:
# Rows in Dataframe:  222
#       period    seriesId                                  seriesDescription  \
# 0    2023-01  CLEPCNS_TX  Electric power sector  consumption of coal, Te...
# 1    2023-01  PAEPGEN_TX  Electric power sector net generation from petr...
# 2    2023-01  CLEPGEN_TX  Electric power sector net generation from coal...
# 3    2023-01  NGEPGEN_TX  Electric power sector net generation from natu...
# 4    2023-01  NGEPCNS_TX  Electric power sector  consumption of natural ...
# ..       ...         ...                                                ...
# 217  2020-01  CLEPGEN_TX  Electric power sector net generation from coal...
# 218  2020-01  PAEPGEN_TX  Electric power sector net generation from petr...
# 219  2020-01  NGEPGEN_TX  Electric power sector net generation from natu...
# 220  2020-01  PAEPCNS_TX  Electric power sector  consumption of petroleu...
# 221  2020-01  NGEPCNS_TX  Electric power sector  consumption of natural ...
#
#            value                   unit
# 0    2542.258000    thousand short tons
# 1       0.008990  billion kilowatthours
# 2       3.350762  billion kilowatthours
# 3      12.517534  billion kilowatthours
# 4     103.396003     billion cubic feet
# ..           ...                    ...
# 217     4.364575  billion kilowatthours
# 218     0.002527  billion kilowatthours
# 219    12.775476  billion kilowatthours
# 220     4.997000       thousand barrels
# 221   101.322595     billion cubic feet
#
# [222 rows x 5 columns]

# %%
# Create series dataframe
gen_series_df = gen_data_df[["seriesId", "seriesDescription"]].drop_duplicates(ignore_index=True)
gen_series_df = gen_series_df.rename(columns={"seriesId": "series", "seriesDescription": "series-description"}).set_index("series")
gen_series_df
# Out:
#                                            series-description
# series
# CLEPCNS_TX  Electric power sector  consumption of coal, Te...
# PAEPGEN_TX  Electric power sector net generation from petr...
# CLEPGEN_TX  Electric power sector net generation from coal...
# NGEPGEN_TX  Electric power sector net generation from natu...
# NGEPCNS_TX  Electric power sector  consumption of natural ...
# PAEPCNS_TX  Electric power sector  consumption of petroleu...

# %%
# Merge Series Dataframe to have complete set
full_series_df = pd.merge(larger_series_df, gen_series_df, how="outer", on=["series", "series-description"])
full_series_df
# Out:
#                                              series-description
# series
# N3045TX3      Texas Natural Gas Price Sold to Electric Power...
# N3010TX3      Texas Price of Natural Gas Delivered to Reside...
# NA1504_STX_4  Texas Natural Gas % of Total Residential - Sal...
# N3035TX4      Percent of Industrial Natural Gas Deliveries i...
# N3020TX4      Percent of Commercial Natural Gas Deliveries i...
# N3020TX3      Texas Price of Natural Gas Sold to Commercial ...
# N3050TX3      Natural Gas Citygate Price in Texas (Dollars p...
# N3035TX3      Texas Natural Gas Industrial Price (Dollars pe...
# TXCCBUS       Total Primary Energy Consumed by the Commercia...
# TXEIEUS       Total Energy Electric Power Sector CO2 Emissio...
# TXICBUS       Total Primary Energy Consumed by the Industria...
# TXRCBUS       Total Primary Energy Consumed by the Residenti...
# CLEPCNS_TX    Electric power sector  consumption of coal, Te...
# PAEPGEN_TX    Electric power sector net generation from petr...
# CLEPGEN_TX    Electric power sector net generation from coal...
# NGEPGEN_TX    Electric power sector net generation from natu...
# NGEPCNS_TX    Electric power sector  consumption of natural ...
# PAEPCNS_TX    Electric power sector  consumption of petroleu...

# %%
# Drop now-redundant column
gen_data_df = gen_data_df.drop(columns=["seriesDescription"])
gen_data_df
# Out:
#       period    seriesId        value                   unit
# 0    2023-01  CLEPCNS_TX  2542.258000    thousand short tons
# 1    2023-01  PAEPGEN_TX     0.008990  billion kilowatthours
# 2    2023-01  CLEPGEN_TX     3.350762  billion kilowatthours
# 3    2023-01  NGEPGEN_TX    12.517534  billion kilowatthours
# 4    2023-01  NGEPCNS_TX   103.396003     billion cubic feet
# ..       ...         ...          ...                    ...
# 217  2020-01  CLEPGEN_TX     4.364575  billion kilowatthours
# 218  2020-01  PAEPGEN_TX     0.002527  billion kilowatthours
# 219  2020-01  NGEPGEN_TX    12.775476  billion kilowatthours
# 220  2020-01  PAEPCNS_TX     4.997000       thousand barrels
# 221  2020-01  NGEPCNS_TX   101.322595     billion cubic feet
#
# [222 rows x 4 columns]

# %%
# Export Dataframes to CSV for importing into SQL
full_series_df.to_csv("Output/Series_DF.csv")
gen_data_df.to_csv("Output/Generation_and_Consumption_DF.csv")

# %%
df = gen_data_df
# Line plot of Electric Power Sector Net Generation from Petroleum, Natural Gas, and Coal
petroleum_generation = df[df['seriesId'] == 'PAEPGEN_TX']
natural_gas_generation = df[df['seriesId'] == 'NGEPGEN_TX']
coal_generation = df[df['seriesId'] == 'CLEPGEN_TX']
# Sort data by 'period' column in ascending order
petroleum_generation = petroleum_generation.sort_values('period')
natural_gas_generation = natural_gas_generation.sort_values('period')
coal_generation = coal_generation.sort_values('period')
plt.figure(figsize=(10, 6))
plt.plot(petroleum_generation['period'], petroleum_generation['value'], label='Petroleum')
plt.plot(natural_gas_generation['period'], natural_gas_generation['value'], label='Natural Gas')
plt.plot(coal_generation['period'], coal_generation['value'], label='Coal')
plt.xlabel('Period')
plt.ylabel('Net Generation (billion kilowatthours)')
plt.title('Electric Power Sector Net Generation')
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.savefig('Images/net_generation.png', dpi=300)

# %%
# Line plot of Electric Power Sector Consumption of Natural Gas
natural_gas_consumption = df[df['seriesId'] == 'NGEPCNS_TX']
natural_gas_consumption = natural_gas_consumption.sort_values('period')
plt.figure(figsize=(10, 6))
plt.plot(natural_gas_consumption['period'], natural_gas_consumption['value'])
plt.xlabel('Period')
plt.ylabel('Natural Gas Consumption (billion cubic feet)')
plt.title('Electric Power Sector Consumption of Natural Gas')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.savefig('Images/ng_consumption.png', dpi=300)

# %%
# Line plot of Electric Power Sector Consumption of Petroleum
petroleum_consumption = df[df['seriesId'] == 'PAEPGEN_TX']
petroleum_consumption = petroleum_consumption.sort_values('period')
plt.figure(figsize=(10, 6))
plt.plot(petroleum_consumption['period'], petroleum_consumption['value'])
plt.xlabel('Period')
plt.ylabel('Petroleum Consumption (thousand barrels)')
plt.title('Electric Power Sector Consumption of Petroleum')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.savefig('Images/petroleum_consumption.png', dpi=300)

# %%
# Line plot of Electric Power Sector Consumption of Coal
coal_consumption = df[df['seriesId'] == 'CLEPGEN_TX']
coal_consumption = coal_consumption.sort_values('period')
plt.figure(figsize=(10, 6))
plt.plot(coal_consumption['period'], coal_consumption['value'])
plt.xlabel('Period')
plt.ylabel('Coal Consumption (thousand short tons)')
plt.title('Electric Power Sector Consumption of Coal')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.savefig('Images/coal_consumption.png', dpi=300)
