# %%
# Import Dependencies
import requests
import pprint
import pandas as pd
# Import the EIA API key
from config import EIA_api_key

# %%
# Define the API key and endpoint URL
api_key = EIA_api_key

# Set the query parameters

# URL endpoint
url = f"https://api.eia.gov/v2/electricity/state-electricity-profiles/capability/data/?api_key={api_key}&frequency=annual&data[0]=capability&facets[stateId][]=TX&start=1990&end=2012&sort[0][column]=period&sort[0][direction]=desc&sort[1][column]=producertypeid&sort[1][direction]=desc&offset=0&length=5000"

try:
    # Send the API request
    response = requests.get(url)
    response.raise_for_status()

    # Retrieve the data
    data = response.json()

    # Process the data as needed
    if "data" in data["response"]:
        # Extract the generator counts by location and energy source
        generator_counts = data["response"]["data"]
        pprint.pprint(data)
        
    else:
        print("No data available.")
except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
# Out:
# {'apiVersion': '2.1.4',
#  'request': {'command': '/v2/electricity/state-electricity-profiles/capability/data/',
#              'params': {'api_key': 'x6MMEhX0n69TOHYg6HfanNHKFatn9wv68dbefLC7',
#                         'data': ['capability'],
#                         'end': 2012,
#                         'facets': {'stateId': ['TX']},
#                         'frequency': 'annual',
#                         'length': 5000,
#                         'offset': 0,
#                         'sort': [{'column': 'period', 'direction': 'desc'},
#                                  {'column': 'producertypeid',
#                                   'direction': 'desc'}],
#                         'start': 1990}},
#  'response': {'data': [{'capability': 109568.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 320.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wood',
#                         'energysourceid': 'WOO',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 12178.9,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wind',
#                         'energysourceid': 'WND',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 75.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar - PV',
#                         'energysourceid': 'SOLPV',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 75.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar',
#                         'energysourceid': 'SOL',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 434.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - ST',
#                         'energysourceid': 'PETST',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 62.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - IC',
#                         'energysourceid': 'PETIC',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 497.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 345.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Gas',
#                         'energysourceid': 'OOG',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 120.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Biomass',
#                         'energysourceid': 'OBM',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 228.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4960,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 22249.1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - ST',
#                         'energysourceid': 'NGST',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 426.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - IC',
#                         'energysourceid': 'NGIC',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 7374.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - GT',
#                         'energysourceid': 'NGGT',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 36933.7,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - CC',
#                         'energysourceid': 'NGCC',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 66983.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 689.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 23132.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 37,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Battery',
#                         'energysourceid': 'BAT',
#                         'period': 2012,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 81105.7,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 320.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wood',
#                         'energysourceid': 'WOO',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 12099.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wind',
#                         'energysourceid': 'WND',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 75.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar - PV',
#                         'energysourceid': 'SOLPV',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 75.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar',
#                         'energysourceid': 'SOL',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 434.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - ST',
#                         'energysourceid': 'PETST',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 47.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - IC',
#                         'energysourceid': 'PETIC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 482,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 345.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Gas',
#                         'energysourceid': 'OOG',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 120.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Biomass',
#                         'energysourceid': 'OBM',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 228.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4960,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 12013.1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - ST',
#                         'energysourceid': 'NGST',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 38.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - IC',
#                         'energysourceid': 'NGIC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4850.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - GT',
#                         'energysourceid': 'NGGT',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 32137.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - CC',
#                         'energysourceid': 'NGCC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 49039.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 7.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 13390.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 37,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Battery',
#                         'energysourceid': 'BAT',
#                         'period': 2012,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 28462.7,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 79.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wind',
#                         'energysourceid': 'WND',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 15.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - IC',
#                         'energysourceid': 'PETIC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 15.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 10236,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - ST',
#                         'energysourceid': 'NGST',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 388,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - IC',
#                         'energysourceid': 'NGIC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 2523.9,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - GT',
#                         'energysourceid': 'NGGT',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4795.9,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - CC',
#                         'energysourceid': 'NGCC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 17943.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 682.1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 9742,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 2012,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 109178.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 216.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wood',
#                         'energysourceid': 'WOO',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 10361.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wind',
#                         'energysourceid': 'WND',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 43.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar - PV',
#                         'energysourceid': 'SOLPV',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 43.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar',
#                         'energysourceid': 'SOL',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 145.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - ST',
#                         'energysourceid': 'PETST',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 62,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - IC',
#                         'energysourceid': 'PETIC',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 207.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 305.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Gas',
#                         'energysourceid': 'OOG',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 125.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Biomass',
#                         'energysourceid': 'OBM',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 227.7,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4960,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 23770.1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - ST',
#                         'energysourceid': 'NGST',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 423,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - IC',
#                         'energysourceid': 'NGIC',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 7469.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - GT',
#                         'energysourceid': 'NGGT',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 37197.7,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - CC',
#                         'energysourceid': 'NGCC',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 68860.1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 689.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 23180.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Battery',
#                         'energysourceid': 'BAT',
#                         'period': 2011,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 81789.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 216.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wood',
#                         'energysourceid': 'WOO',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 10281.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wind',
#                         'energysourceid': 'WND',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 43.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar - PV',
#                         'energysourceid': 'SOLPV',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 43.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar',
#                         'energysourceid': 'SOL',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 145.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - ST',
#                         'energysourceid': 'PETST',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 47.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - IC',
#                         'energysourceid': 'PETIC',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 192.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 305.6,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Gas',
#                         'energysourceid': 'OOG',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 125.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Biomass',
#                         'energysourceid': 'OBM',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 227.7,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4960,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 13419.1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - ST',
#                         'energysourceid': 'NGST',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 35,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - IC',
#                         'energysourceid': 'NGIC',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 4912.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - GT',
#                         'energysourceid': 'NGGT',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 33643.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas - CC',
#                         'energysourceid': 'NGCC',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 52010.3,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 7.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 13417.4,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 1,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Battery',
#                         'energysourceid': 'BAT',
#                         'period': 2011,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 27389.2,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 2011,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 79.5,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wind',
#                         'energysourceid': 'WND',
#                         'period': 2011,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 14.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum - IC',
#                         'energysourceid': 'PETIC',
#                         'period': 2011,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 14.8,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 2011,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 10351,
#                         'capability-units': 'megawatts',
# ...
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 178,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 1991,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 3650,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 1991,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 38117,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 1991,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 640,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 1991,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 18776,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 1991,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 68383,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 132,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wood',
#                         'energysourceid': 'WOO',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 0,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar',
#                         'energysourceid': 'SOL',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 314,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 252,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Gas',
#                         'energysourceid': 'OOG',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 10,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Biomass',
#                         'energysourceid': 'OBM',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 373,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 3651,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 44084,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 640,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 18928,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 1990,
#                         'producerTypeDescription': 'All sectors',
#                         'producertypeid': 'TOT',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 7122,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 132,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Wood',
#                         'energysourceid': 'WOO',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 258,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 252,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Gas',
#                         'energysourceid': 'OOG',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 10,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other Biomass',
#                         'energysourceid': 'OBM',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 70,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 6064,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 338,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 1990,
#                         'producerTypeDescription': 'Independent Power '
#                                                    'Producers',
#                         'producertypeid': 'IPP',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 61261,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'All',
#                         'energysourceid': 'ALL',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 18590,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Coal',
#                         'energysourceid': 'COL',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 640,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Hydroelectric',
#                         'energysourceid': 'HYC',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 38020,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Natural Gas',
#                         'energysourceid': 'NG',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 3651,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Nuclear',
#                         'energysourceid': 'NUC',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 303,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Other',
#                         'energysourceid': 'OT',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 56,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Petroleum',
#                         'energysourceid': 'PET',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'},
#                        {'capability': 0,
#                         'capability-units': 'megawatts',
#                         'energySourceDescription': 'Solar',
#                         'energysourceid': 'SOL',
#                         'period': 1990,
#                         'producerTypeDescription': 'Electric Utilities',
#                         'producertypeid': 'EU',
#                         'stateDescription': 'Texas',
#                         'stateId': 'TX'}],
#               'dateFormat': 'YYYY',
#               'description': 'Electric generating capacity (summer capacity) '
#                              'by state, energy source, and sector.\n'
#                              '    Source: Form EIA-860\n'
#                              '    Product: State Electricity Profiles, Table 4',
#               'frequency': 'annual',
#               'total': 772}}

# %%
# Convert JSON file to Pandas Dataframe and confirm # of rows matches original file
data_df = pd.json_normalize(data["response"]["data"])
print("Rows in Dataframe: ", len(data_df))
data_df.head()
# Out:
# Rows in Dataframe:  772
#    period stateId stateDescription producertypeid producerTypeDescription  \
# 0    2012      TX            Texas            TOT             All sectors
# 1    2012      TX            Texas            TOT             All sectors
# 2    2012      TX            Texas            TOT             All sectors
# 3    2012      TX            Texas            TOT             All sectors
# 4    2012      TX            Texas            TOT             All sectors
#
#   energysourceid energySourceDescription  capability capability-units
# 0            ALL                     All    109568.4        megawatts
# 1            WOO                    Wood       320.3        megawatts
# 2            WND                    Wind     12178.9        megawatts
# 3          SOLPV              Solar - PV        75.2        megawatts
# 4            SOL                   Solar        75.2        megawatts

# %%
# Create Producer Types dataframe 
producer_types_df = data_df[["producertypeid","producerTypeDescription"]]
producer_types_df = producer_types_df.sort_values("producertypeid").drop_duplicates(ignore_index=True)
producer_types_df = producer_types_df.set_index("producertypeid")
producer_types_df
# Out:
#                     producerTypeDescription
# producertypeid
# EU                       Electric Utilities
# IPP             Independent Power Producers
# TOT                             All sectors

# %%
# Create Energy Sources dataframe
energy_sources_df = data_df[["energysourceid", "energySourceDescription"]]
energy_sources_df = energy_sources_df.sort_values("energysourceid").drop_duplicates(ignore_index=True)
energy_sources_df = energy_sources_df.set_index("energysourceid")
energy_sources_df
# Out:
#                energySourceDescription
# energysourceid
# ALL                                All
# BAT                            Battery
# COL                               Coal
# HYC                      Hydroelectric
# NG                         Natural Gas
# NGCC                  Natural Gas - CC
# NGGT                  Natural Gas - GT
# NGIC                  Natural Gas - IC
# NGOTH                Natural Gas - OTH
# NGST                  Natural Gas - ST
# NUC                            Nuclear
# OBM                      Other Biomass
# OOG                          Other Gas
# OT                               Other
# PET                          Petroleum
# PETIC                   Petroleum - IC
# PETOTH                 Petroleum - OTH
# PETST                   Petroleum - ST
# SOL                              Solar
# SOLPV                       Solar - PV
# WND                               Wind
# WOO                               Wood

# %%
# Create States dataframe
states_df = data_df[["stateId", "stateDescription"]].drop_duplicates(ignore_index=True)
states_df = states_df.set_index("stateId")
states_df
# Out:
#         stateDescription
# stateId
# TX                 Texas

# %%
# Drop columns to create cleaner Generating Capacity dataframe
generating_df = data_df[["period", "stateId", "producertypeid", "energysourceid", "capability", "capability-units"]]
generating_df.head()
# Out:
#    period stateId producertypeid energysourceid  capability capability-units
# 0    2012      TX            TOT            ALL    109568.4        megawatts
# 1    2012      TX            TOT            WOO       320.3        megawatts
# 2    2012      TX            TOT            WND     12178.9        megawatts
# 3    2012      TX            TOT          SOLPV        75.2        megawatts
# 4    2012      TX            TOT            SOL        75.2        megawatts

# %%
# Export all Dataframes to CSV for importing into SQL
energy_sources_df.to_csv("Energy_Sources_DF.csv")
producer_types_df.to_csv("Producer_Types_DF.csv")
states_df.to_csv("States_DF.csv")
generating_df.to_csv("Generating_Capacity_DF.csv")

# %% [markdown]
# Other Tests

# %%
# Generator details - January 2023 only
url = f"https://api.eia.gov/v2/electricity/operating-generator-capacity/data/?api_key={api_key}&frequency=monthly&data[0]=latitude&data[1]=longitude&facets[stateid][]=TX&start=2023-01&end=2023-01&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
response = requests.get(url)
response.raise_for_status()

# Retrieve the data
data2 = response.json()

    # Process the data as needed
if "data" in data2["response"]:
    # Extract the generator counts by location and energy source
    pprint.pprint(data2)
# Out:
# {'apiVersion': '2.1.4',
#  'request': {'command': '/v2/electricity/operating-generator-capacity/data/',
#              'params': {'api_key': 'x6MMEhX0n69TOHYg6HfanNHKFatn9wv68dbefLC7',
#                         'data': ['latitude', 'longitude'],
#                         'end': '2023-01',
#                         'facets': {'stateid': ['TX']},
#                         'frequency': 'monthly',
#                         'length': 5000,
#                         'offset': 0,
#                         'sort': [{'column': 'period', 'direction': 'desc'}],
#                         'start': '2023-01'}},
#  'response': {'data': [{'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'GT1',
#                         'latitude': 30.3033,
#                         'longitude': -97.6128,
#                         'period': '2023-01',
#                         'plantName': 'Decker Creek',
#                         'plantid': 3548,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'GT2',
#                         'latitude': 30.3033,
#                         'longitude': -97.6128,
#                         'period': '2023-01',
#                         'plantName': 'Decker Creek',
#                         'plantid': 3548,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'GT3',
#                         'latitude': 30.3033,
#                         'longitude': -97.6128,
#                         'period': '2023-01',
#                         'plantName': 'Decker Creek',
#                         'plantid': 3548,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'BASF Corporation',
#                         'entityid': 1182,
#                         'generatorid': 'GEN1',
#                         'latitude': 29.002,
#                         'longitude': -95.394,
#                         'period': '2023-01',
#                         'plantName': 'BASF Freeport Works',
#                         'plantid': 55311,
#                         'prime_mover_code': 'GT',
#                         'sector': 'industrial-chp',
#                         'sectorName': 'Industrial CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Waste Heat',
#                         'energy_source_code': 'WH',
#                         'entityName': 'BASF Corporation',
#                         'entityid': 1182,
#                         'generatorid': 'GEN2',
#                         'latitude': 29.002,
#                         'longitude': -95.394,
#                         'period': '2023-01',
#                         'plantName': 'BASF Freeport Works',
#                         'plantid': 55311,
#                         'prime_mover_code': 'ST',
#                         'sector': 'industrial-chp',
#                         'sectorName': 'Industrial CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'All Other',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'GT4',
#                         'latitude': 30.3033,
#                         'longitude': -97.6128,
#                         'period': '2023-01',
#                         'plantName': 'Decker Creek',
#                         'plantid': 3548,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': '5A',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'CT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC1'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': '5C',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'CA',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC1'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'SH1',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'SH2',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'SH3',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'SH4',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'SH6',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'SH7',
#                         'latitude': 30.2098,
#                         'longitude': -97.6129,
#                         'period': '2023-01',
#                         'plantName': 'Sand Hill',
#                         'plantid': 7900,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Wood Waste Solids',
#                         'energy_source_code': 'WDS',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'STG4',
#                         'latitude': 31.832132,
#                         'longitude': -94.90064,
#                         'period': '2023-01',
#                         'plantName': 'Nacogdoches Power',
#                         'plantid': 55708,
#                         'prime_mover_code': 'ST',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Wood/Wood Waste Biomass',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'CT1',
#                         'latitude': 30.304994,
#                         'longitude': -97.707675,
#                         'period': '2023-01',
#                         'plantName': 'Robert Mueller Energy Center',
#                         'plantid': 56374,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Disillate Fuel Oil',
#                         'energy_source_code': 'DFO',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'DG1',
#                         'latitude': 30.304994,
#                         'longitude': -97.707675,
#                         'period': '2023-01',
#                         'plantName': 'Robert Mueller Energy Center',
#                         'plantid': 56374,
#                         'prime_mover_code': 'IC',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'SB',
#                         'statusDescription': 'Standby/Backup: available for '
#                                              'service but not normally used',
#                         'technology': 'Petroleum Liquids',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Occidental Permian Ltd',
#                         'entityid': 429,
#                         'generatorid': 'GEN1',
#                         'latitude': 33.009944,
#                         'longitude': -102.756945,
#                         'period': '2023-01',
#                         'plantName': 'Wasson CO2 Removal Plant',
#                         'plantid': 52122,
#                         'prime_mover_code': 'GT',
#                         'sector': 'industrial-chp',
#                         'sectorName': 'Industrial CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'BASF Corp',
#                         'entityid': 1357,
#                         'generatorid': 'UN1',
#                         'latitude': 29.954321,
#                         'longitude': -93.883592,
#                         'period': '2023-01',
#                         'plantName': 'NAFTA Region Olefins Complex Cogen Fac',
#                         'plantid': 55122,
#                         'prime_mover_code': 'GT',
#                         'sector': 'industrial-chp',
#                         'sectorName': 'Industrial CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'BASF Corp',
#                         'entityid': 1357,
#                         'generatorid': 'UN2',
#                         'latitude': 29.954321,
#                         'longitude': -93.883592,
#                         'period': '2023-01',
#                         'plantName': 'NAFTA Region Olefins Complex Cogen Fac',
#                         'plantid': 55122,
#                         'prime_mover_code': 'GT',
#                         'sector': 'industrial-chp',
#                         'sectorName': 'Industrial CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'CT3',
#                         'latitude': 33.101,
#                         'longitude': -97.9574,
#                         'period': '2023-01',
#                         'plantName': 'Jack County',
#                         'plantid': 55230,
#                         'prime_mover_code': 'CT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC02'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'CT4',
#                         'latitude': 33.101,
#                         'longitude': -97.9574,
#                         'period': '2023-01',
#                         'plantName': 'Jack County',
#                         'plantid': 55230,
#                         'prime_mover_code': 'CT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC02'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'ST1',
#                         'latitude': 33.101,
#                         'longitude': -97.9574,
#                         'period': '2023-01',
#                         'plantName': 'Jack County',
#                         'plantid': 55230,
#                         'prime_mover_code': 'CA',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC01'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'ST2',
#                         'latitude': 33.101,
#                         'longitude': -97.9574,
#                         'period': '2023-01',
#                         'plantName': 'Jack County',
#                         'plantid': 55230,
#                         'prime_mover_code': 'CA',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC02'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 1,
#                         'latitude': 32.6581,
#                         'longitude': -98.3103,
#                         'period': '2023-01',
#                         'plantName': 'R W Miller',
#                         'plantid': 3628,
#                         'prime_mover_code': 'ST',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OS',
#                         'statusDescription': 'Out of service and NOT expected '
#                                              'to return to service in next '
#                                              'calendar year',
#                         'technology': 'Natural Gas Steam Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Valley Energy',
#                         'entityid': 2171,
#                         'generatorid': 'CTG1',
#                         'latitude': 29.4731,
#                         'longitude': -95.6244,
#                         'period': '2023-01',
#                         'plantName': 'Jack Fusco Energy Center',
#                         'plantid': 55357,
#                         'prime_mover_code': 'CT',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'STG1'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Valley Energy',
#                         'entityid': 2171,
#                         'generatorid': 'CTG2',
#                         'latitude': 29.4731,
#                         'longitude': -95.6244,
#                         'period': '2023-01',
#                         'plantName': 'Jack Fusco Energy Center',
#                         'plantid': 55357,
#                         'prime_mover_code': 'CT',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'STG1'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Valley Energy',
#                         'entityid': 2171,
#                         'generatorid': 'STG1',
#                         'latitude': 29.4731,
#                         'longitude': -95.6244,
#                         'period': '2023-01',
#                         'plantName': 'Jack Fusco Energy Center',
#                         'plantid': 55357,
#                         'prime_mover_code': 'CA',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'STG1'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 2,
#                         'latitude': 32.6581,
#                         'longitude': -98.3103,
#                         'period': '2023-01',
#                         'plantName': 'R W Miller',
#                         'plantid': 3628,
#                         'prime_mover_code': 'ST',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Steam Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 3,
#                         'latitude': 32.6581,
#                         'longitude': -98.3103,
#                         'period': '2023-01',
#                         'plantName': 'R W Miller',
#                         'plantid': 3628,
#                         'prime_mover_code': 'ST',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Steam Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 4,
#                         'latitude': 32.6581,
#                         'longitude': -98.3103,
#                         'period': '2023-01',
#                         'plantName': 'R W Miller',
#                         'plantid': 3628,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 5,
#                         'latitude': 32.6581,
#                         'longitude': -98.3103,
#                         'period': '2023-01',
#                         'plantName': 'R W Miller',
#                         'plantid': 3628,
#                         'prime_mover_code': 'GT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'GT-1',
#                         'latitude': 32.3994,
#                         'longitude': -97.4078,
#                         'period': '2023-01',
#                         'plantName': 'Johnson County',
#                         'plantid': 54817,
#                         'prime_mover_code': 'CT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC01'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'ST-1',
#                         'latitude': 32.3994,
#                         'longitude': -97.4078,
#                         'period': '2023-01',
#                         'plantName': 'Johnson County',
#                         'plantid': 54817,
#                         'prime_mover_code': 'CA',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC01'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'CT1',
#                         'latitude': 33.101,
#                         'longitude': -97.9574,
#                         'period': '2023-01',
#                         'plantName': 'Jack County',
#                         'plantid': 55230,
#                         'prime_mover_code': 'CT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC01'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Brazos Electric Power Coop Inc',
#                         'entityid': 2172,
#                         'generatorid': 'CT2',
#                         'latitude': 33.101,
#                         'longitude': -97.9574,
#                         'period': '2023-01',
#                         'plantName': 'Jack County',
#                         'plantid': 55230,
#                         'prime_mover_code': 'CT',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': 'CC01'},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Total Petrochemicals USA Inc',
#                         'entityid': 914,
#                         'generatorid': 'GEN1',
#                         'latitude': 29.964938,
#                         'longitude': -93.891283,
#                         'period': '2023-01',
#                         'plantName': 'Port Arthur Texas Refinery',
#                         'plantid': 10568,
#                         'prime_mover_code': 'GT',
#                         'sector': 'industrial-chp',
#                         'sectorName': 'Industrial CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combustion Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Electricity used for energy '
#                                               'storage',
#                         'energy_source_code': 'MWH',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'KBESS',
#                         'latitude': 30.266028,
#                         'longitude': -97.686139,
#                         'period': '2023-01',
#                         'plantName': 'Kingsberry Energy Storage System',
#                         'plantid': 61741,
#                         'prime_mover_code': 'BA',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Batteries',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Electricity used for energy '
#                                               'storage',
#                         'energy_source_code': 'MWH',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'GEN1',
#                         'latitude': 30.219946,
#                         'longitude': -97.708808,
#                         'period': '2023-01',
#                         'plantName': 'System Control Center',
#                         'plantid': 61742,
#                         'prime_mover_code': 'FW',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'SB',
#                         'statusDescription': 'Standby/Backup: available for '
#                                              'service but not normally used',
#                         'technology': 'Flywheels',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Electricity used for energy '
#                                               'storage',
#                         'energy_source_code': 'MWH',
#                         'entityName': 'Austin Energy',
#                         'entityid': 1015,
#                         'generatorid': 'GEN2',
#                         'latitude': 30.219946,
#                         'longitude': -97.708808,
#                         'period': '2023-01',
#                         'plantName': 'System Control Center',
#                         'plantid': 61742,
#                         'prime_mover_code': 'FW',
#                         'sector': 'electric-utility',
#                         'sectorName': 'Electric Utility',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'SB',
#                         'statusDescription': 'Standby/Backup: available for '
#                                              'service but not normally used',
#                         'technology': 'Flywheels',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Hays Energy, LLC',
#                         'entityid': 1074,
#                         'generatorid': 'U4',
#                         'latitude': 29.7806,
#                         'longitude': -97.9894,
#                         'period': '2023-01',
#                         'plantName': 'Hays Energy Project',
#                         'plantid': 55144,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Hays Energy, LLC',
#                         'entityid': 1074,
#                         'generatorid': 'U1',
#                         'latitude': 29.7806,
#                         'longitude': -97.9894,
#                         'period': '2023-01',
#                         'plantName': 'Hays Energy Project',
#                         'plantid': 55144,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Hays Energy, LLC',
#                         'entityid': 1074,
#                         'generatorid': 'U2',
#                         'latitude': 29.7806,
#                         'longitude': -97.9894,
#                         'period': '2023-01',
#                         'plantName': 'Hays Energy Project',
#                         'plantid': 55144,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Hays Energy, LLC',
#                         'entityid': 1074,
#                         'generatorid': 'U3',
#                         'latitude': 29.7806,
#                         'longitude': -97.9894,
#                         'period': '2023-01',
#                         'plantName': 'Hays Energy Project',
#                         'plantid': 55144,
# ...
#                         'entityName': 'Verizon Communications',
#                         'entityid': 64808,
#                         'generatorid': 'VH600',
#                         'latitude': 32.87662,
#                         'longitude': -96.95372,
#                         'period': '2023-01',
#                         'plantName': 'Verizon Hidden Ridge Solar Project',
#                         'plantid': 65571,
#                         'prime_mover_code': 'PV',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Solar Photovoltaic',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Solar',
#                         'energy_source_code': 'SUN',
#                         'entityName': 'Verizon Communications',
#                         'entityid': 64808,
#                         'generatorid': 'VH700',
#                         'latitude': 32.87662,
#                         'longitude': -96.95372,
#                         'period': '2023-01',
#                         'plantName': 'Verizon Hidden Ridge Solar Project',
#                         'plantid': 65571,
#                         'prime_mover_code': 'PV',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Solar Photovoltaic',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Wind',
#                         'energy_source_code': 'WND',
#                         'entityName': 'Helena Wind, LLC',
#                         'entityid': 63437,
#                         'generatorid': 'HEL',
#                         'latitude': 28.621959,
#                         'longitude': -97.937625,
#                         'period': '2023-01',
#                         'plantName': 'Helena Wind',
#                         'plantid': 63738,
#                         'prime_mover_code': 'WT',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Onshore Wind Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Wind',
#                         'energy_source_code': 'WND',
#                         'entityName': 'Electra Wind, LLC',
#                         'entityid': 60128,
#                         'generatorid': 'EWF',
#                         'latitude': 34.102943,
#                         'longitude': -99.118746,
#                         'period': '2023-01',
#                         'plantName': 'Electra Wind Farm',
#                         'plantid': 60338,
#                         'prime_mover_code': 'WT',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Onshore Wind Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Wind',
#                         'energy_source_code': 'WND',
#                         'entityName': 'Horse Creek Wind, LLC',
#                         'entityid': 60129,
#                         'generatorid': 'HCWF',
#                         'latitude': 33.35,
#                         'longitude': -99.54,
#                         'period': '2023-01',
#                         'plantName': 'Horse Creek Wind Farm',
#                         'plantid': 60339,
#                         'prime_mover_code': 'WT',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Onshore Wind Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Solar',
#                         'energy_source_code': 'SUN',
#                         'entityName': 'Ameresco Federal Solutions',
#                         'entityid': 60146,
#                         'generatorid': 'DEPIC',
#                         'latitude': 31.829986,
#                         'longitude': -106.372861,
#                         'period': '2023-01',
#                         'plantName': 'Fort Bliss (DEA EPIC)',
#                         'plantid': 61887,
#                         'prime_mover_code': 'PV',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Solar Photovoltaic',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Wind',
#                         'energy_source_code': 'WND',
#                         'entityName': 'Old Settler Wind, LLC',
#                         'entityid': 60155,
#                         'generatorid': 'OSWF',
#                         'latitude': 34.060333,
#                         'longitude': -101.187628,
#                         'period': '2023-01',
#                         'plantName': 'Old Settler Wind',
#                         'plantid': 60366,
#                         'prime_mover_code': 'WT',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Onshore Wind Turbine',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Solar',
#                         'energy_source_code': 'SUN',
#                         'entityName': 'MN8 Energy LLC',
#                         'entityid': 61944,
#                         'generatorid': 1,
#                         'latitude': 29.6,
#                         'longitude': -104.3,
#                         'period': '2023-01',
#                         'plantName': 'Bryan Solar, LLC',
#                         'plantid': 58488,
#                         'prime_mover_code': 'PV',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Solar Photovoltaic',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Solar',
#                         'energy_source_code': 'SUN',
#                         'entityName': 'MN8 Energy LLC',
#                         'entityid': 61944,
#                         'generatorid': 'TOYHQ',
#                         'latitude': 33.084219,
#                         'longitude': -96.84113,
#                         'period': '2023-01',
#                         'plantName': 'Toyota HQ Plan',
#                         'plantid': 61895,
#                         'prime_mover_code': 'PV',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Solar Photovoltaic',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Midlothian Energy LLC',
#                         'entityid': 12501,
#                         'generatorid': 'STK1',
#                         'latitude': 32.4302,
#                         'longitude': -97.0537,
#                         'period': '2023-01',
#                         'plantName': 'Midlothian Energy Facility',
#                         'plantid': 55091,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Midlothian Energy LLC',
#                         'entityid': 12501,
#                         'generatorid': 'STK2',
#                         'latitude': 32.4302,
#                         'longitude': -97.0537,
#                         'period': '2023-01',
#                         'plantName': 'Midlothian Energy Facility',
#                         'plantid': 55091,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Midlothian Energy LLC',
#                         'entityid': 12501,
#                         'generatorid': 'STK3',
#                         'latitude': 32.4302,
#                         'longitude': -97.0537,
#                         'period': '2023-01',
#                         'plantName': 'Midlothian Energy Facility',
#                         'plantid': 55091,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Midlothian Energy LLC',
#                         'entityid': 12501,
#                         'generatorid': 'STK4',
#                         'latitude': 32.4302,
#                         'longitude': -97.0537,
#                         'period': '2023-01',
#                         'plantName': 'Midlothian Energy Facility',
#                         'plantid': 55091,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Midlothian Energy LLC',
#                         'entityid': 12501,
#                         'generatorid': 'STK5',
#                         'latitude': 32.4302,
#                         'longitude': -97.0537,
#                         'period': '2023-01',
#                         'plantName': 'Midlothian Energy Facility',
#                         'plantid': 55091,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None},
#                        {'balancing-authority-name': None,
#                         'balancing_authority_code': None,
#                         'energy-source-desc': 'Natural Gas',
#                         'energy_source_code': 'NG',
#                         'entityName': 'Midlothian Energy LLC',
#                         'entityid': 12501,
#                         'generatorid': 'STK6',
#                         'latitude': 32.4302,
#                         'longitude': -97.0537,
#                         'period': '2023-01',
#                         'plantName': 'Midlothian Energy Facility',
#                         'plantid': 55091,
#                         'prime_mover_code': 'CS',
#                         'sector': 'ipp-non-chp',
#                         'sectorName': 'IPP Non-CHP',
#                         'stateName': 'Texas',
#                         'stateid': 'TX',
#                         'status': 'OP',
#                         'statusDescription': 'Operating',
#                         'technology': 'Natural Gas Fired Combined Cycle',
#                         'unit': None}],
#               'dateFormat': 'YYYY-MM',
#               'description': 'Inventory of operable generators in the U.S.\n'
#                              '    Source: Forms EIA-860, EIA-860M',
#               'frequency': 'monthly',
#               'total': 1821}}

# %%
data2_df = pd.json_normalize(data2["response"]["data"])
print("Rows in Dataframe: ", len(data2_df))
data2_df.head()
# Out:
# Rows in Dataframe:  1821
#     period stateid stateName            sector        sectorName  entityid  \
# 0  2023-01      TX     Texas  electric-utility  Electric Utility      1015
# 1  2023-01      TX     Texas  electric-utility  Electric Utility      1015
# 2  2023-01      TX     Texas  electric-utility  Electric Utility      1015
# 3  2023-01      TX     Texas    industrial-chp    Industrial CHP      1182
# 4  2023-01      TX     Texas    industrial-chp    Industrial CHP      1182
#
#          entityName  plantid            plantName generatorid  ...  \
# 0     Austin Energy     3548         Decker Creek         GT1  ...
# 1     Austin Energy     3548         Decker Creek         GT2  ...
# 2     Austin Energy     3548         Decker Creek         GT3  ...
# 3  BASF Corporation    55311  BASF Freeport Works        GEN1  ...
# 4  BASF Corporation    55311  BASF Freeport Works        GEN2  ...
#
#   energy_source_code energy-source-desc prime_mover_code  \
# 0                 NG        Natural Gas               GT
# 1                 NG        Natural Gas               GT
# 2                 NG        Natural Gas               GT
# 3                 NG        Natural Gas               GT
# 4                 WH         Waste Heat               ST
#
#   balancing_authority_code balancing-authority-name status statusDescription  \
# 0                     None                     None     OP         Operating
# 1                     None                     None     OP         Operating
# 2                     None                     None     OP         Operating
# 3                     None                     None     OP         Operating
# 4                     None                     None     OP         Operating
#
#   latitude  longitude  unit
# 0  30.3033   -97.6128  None
# 1  30.3033   -97.6128  None
# 2  30.3033   -97.6128  None
# 3  29.0020   -95.3940  None
# 4  29.0020   -95.3940  None
#
# [5 rows x 21 columns]

# %%
sector_df = data2_df[["sector", "sectorName"]].drop_duplicates(ignore_index=True)
sector_df = sector_df.set_index("sector")
sector_df
# Out:
#                             sectorName
# sector
# electric-utility      Electric Utility
# industrial-chp          Industrial CHP
# ipp-non-chp                IPP Non-CHP
# ipp-chp                        IPP CHP
# commercial-chp          Commercial CHP
# industrial-non-chp  Industrial Non-CHP
# commercial-non-chp  Commercial Non-CHP

# %%
entity_df = data2_df[["entityid", "entityName"]].drop_duplicates(ignore_index=True)
entity_df = entity_df.set_index("entityid")
entity_df
# Out:
#                               entityName
# entityid
# 1015                       Austin Energy
# 1182                    BASF Corporation
# 429               Occidental Permian Ltd
# 1357                           BASF Corp
# 2172      Brazos Electric Power Coop Inc
# ...                                  ...
# 60129              Horse Creek Wind, LLC
# 60146         Ameresco Federal Solutions
# 60155              Old Settler Wind, LLC
# 61944                     MN8 Energy LLC
# 12501              Midlothian Energy LLC
#
# [375 rows x 1 columns]

# %%
plant_df = data2_df[["plantid", "plantName"]].drop_duplicates(ignore_index=True)
plant_df = plant_df.set_index("plantid")
plant_df
# Out:
#                             plantName
# plantid
# 3548                     Decker Creek
# 55311             BASF Freeport Works
# 7900                        Sand Hill
# 55708               Nacogdoches Power
# 56374    Robert Mueller Energy Center
# ...                               ...
# 61887           Fort Bliss (DEA EPIC)
# 60366                Old Settler Wind
# 58488                Bryan Solar, LLC
# 61895                  Toyota HQ Plan
# 55091      Midlothian Energy Facility
#
# [741 rows x 1 columns]

# %%
status_df = data2_df[["status", "statusDescription"]].drop_duplicates(ignore_index=True)
status_df = status_df.set_index("status")
status_df
# Out:
#                                         statusDescription
# status
# OP                                              Operating
# SB      Standby/Backup: available for service but not ...
# OS      Out of service and NOT expected to return to s...
# OA      Out of service but expected to return to servi...

# %%
list2 = data2_df["balancing-authority-name"].unique()
list2
# Out:
# array([None], dtype=object)

# %%
generators_df = data2_df.drop(columns=["stateName", "sectorName", "entityName", "plantName", "statusDescription", "energy-source-desc", "balancing_authority_code", "balancing-authority-name", "unit"])
generators_df.head()
# Out:
#     period stateid            sector  entityid  plantid generatorid  \
# 0  2023-01      TX  electric-utility      1015     3548         GT1
# 1  2023-01      TX  electric-utility      1015     3548         GT2
# 2  2023-01      TX  electric-utility      1015     3548         GT3
# 3  2023-01      TX    industrial-chp      1182    55311        GEN1
# 4  2023-01      TX    industrial-chp      1182    55311        GEN2
#
#                              technology energy_source_code prime_mover_code  \
# 0  Natural Gas Fired Combustion Turbine                 NG               GT
# 1  Natural Gas Fired Combustion Turbine                 NG               GT
# 2  Natural Gas Fired Combustion Turbine                 NG               GT
# 3  Natural Gas Fired Combustion Turbine                 NG               GT
# 4                             All Other                 WH               ST
#
#   status  latitude  longitude
# 0     OP   30.3033   -97.6128
# 1     OP   30.3033   -97.6128
# 2     OP   30.3033   -97.6128
# 3     OP   29.0020   -95.3940
# 4     OP   29.0020   -95.3940

# %%
# Export all Dataframes to CSV for importing into SQL
sector_df.to_csv("Sector_DF.csv")
entity_df.to_csv("Entity_DF.csv")
plant_df.to_csv("Plant_DF.csv")
status_df.to_csv("Status_DF.csv")
generators_df.to_csv("Generators_DF.csv")

# %%
list3 = generators_df["energy_source_code"].unique()
list3
# Out:
# array(['NG', 'WH', 'WDS', 'DFO', 'MWH', 'WND', 'WAT', 'SUN', 'OG', 'SUB',
#        'LIG', 'AB', 'LFG', 'NUC', 'RC', 'PC', 'PUR', 'BLQ'], dtype=object)
